# %%
from data.helper import *

# %%
DF = get_train_df()
# Out:
# 100%|██████████| 1536/1536 [00:00<00:00, 3381.45it/s]

# %%
COLUMNS = [
    "optimiser",
    "features",
    "iterations",
    "feature_pruning",
    "data_pruning",
]

# %%
for metric in ["n_data", "n_colours", "mse_loss", "f1_macro"]:
    print(metric)
    df = DF.copy()
    df = df[df.facts == "fd"]
    df = df[df.features == "wl"]
    df = df[df.completed]
    Models = {"svr"}
    if metric in {"n_colours", "n_data"}:
        Models.add("rank-svm")
    df = df[df["optimiser"].isin(Models)]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(COLUMNS + ["domain"]).max().reset_index()
    df = df[COLUMNS + ["domain", metric]]
    # pivot table
    df = df.pivot_table(index=COLUMNS, values=metric, columns="domain")
    # make entries int2
    if metric in {"n_colours", "n_data"}:
        df = df.fillna(0)
        df = df.astype(int)
    # display(df)
    # display df without hiding rows
    with pd.option_context("display.max_rows", None):
        display(df)
# Out:
# n_data
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent           7547
#                                                none                 7703
#                               collapse-layer   equivalent           7547
#                                                none                 7703
#                               collapse-layer-x equivalent           7524
#                                                none                 7703
#                               none             equivalent           7547
#                                                none                 7703
#                    4          collapse-all     equivalent           7547
#                                                none                 7703
#                               collapse-layer   equivalent           7547
#                                                none                 7703
#                               collapse-layer-x equivalent           7524
#                                                none                 7703
#                               none             equivalent           7547
#                                                none                 7703
#                    6          collapse-all     equivalent           7547
#                                                none                 7703
#                               collapse-layer   equivalent           7547
#                                                none                 7703
#                               collapse-layer-x equivalent           7524
#                                                none                 7703
#                               none             equivalent              0
#                                                none                    0
# svr       wl       2          collapse-all     equivalent           1247
#                                                none                 1292
#                               collapse-layer   equivalent           1247
#                                                none                 1292
#                               collapse-layer-x equivalent           1242
#                                                none                 1292
#                               none             equivalent           1247
#                                                none                 1292
#                    4          collapse-all     equivalent           1247
#                                                none                 1292
#                               collapse-layer   equivalent           1247
#                                                none                 1292
#                               collapse-layer-x equivalent           1242
#                                                none                 1292
#                               none             equivalent           1247
#                                                none                 1292
#                    6          collapse-all     equivalent           1247
#                                                none                 1292
#                               collapse-layer   equivalent           1247
#                                                none                 1292
#                               collapse-layer-x equivalent           1242
#                                                none                 1292
#                               none             equivalent           1247
#                                                none                 1292
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent          4118
#                                                none               10334
#                               collapse-layer   equivalent          4118
#                                                none               10334
#                               collapse-layer-x equivalent          4118
#                                                none               10334
#                               none             equivalent          4118
#                                                none               10334
#                    4          collapse-all     equivalent          4118
#                                                none               10334
#                               collapse-layer   equivalent          4118
#                                                none               10334
#                               collapse-layer-x equivalent          4118
#                                                none               10334
#                               none             equivalent          4118
#                                                none               10334
#                    6          collapse-all     equivalent          4118
#                                                none               10334
#                               collapse-layer   equivalent          4118
#                                                none               10334
#                               collapse-layer-x equivalent          4118
#                                                none               10334
#                               none             equivalent          4118
#                                                none               10334
# svr       wl       2          collapse-all     equivalent           240
#                                                none                 473
#                               collapse-layer   equivalent           240
#                                                none                 473
#                               collapse-layer-x equivalent           240
#                                                none                 473
#                               none             equivalent           240
#                                                none                 473
#                    4          collapse-all     equivalent           240
#                                                none                 473
#                               collapse-layer   equivalent           240
#                                                none                 473
#                               collapse-layer-x equivalent           240
#                                                none                 473
#                               none             equivalent           240
#                                                none                 473
#                    6          collapse-all     equivalent           240
#                                                none                 473
#                               collapse-layer   equivalent           240
#                                                none                 473
#                               collapse-layer-x equivalent           240
#                                                none                 473
#                               none             equivalent           240
#                                                none                 473
#
# domain                                                       ferry  miconic  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer   equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer-x equivalent    13259    19199
#                                                none          13719    24089
#                               none             equivalent    13259    19199
#                                                none          13719    24089
#                    4          collapse-all     equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer   equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer-x equivalent    13259    19199
#                                                none          13719    24089
#                               none             equivalent    13259    19199
#                                                none          13719    24089
#                    6          collapse-all     equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer   equivalent    13259    19199
#                                                none          13719    24089
#                               collapse-layer-x equivalent    13259    19199
#                                                none          13719    24089
#                               none             equivalent    13259    19199
#                                                none          13719    24089
# svr       wl       2          collapse-all     equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer   equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer-x equivalent     1286     1254
#                                                none           1368     1630
#                               none             equivalent     1286     1254
#                                                none           1368     1630
#                    4          collapse-all     equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer   equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer-x equivalent     1286     1254
#                                                none           1368     1630
#                               none             equivalent     1286     1254
#                                                none           1368     1630
#                    6          collapse-all     equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer   equivalent     1286     1254
#                                                none           1368     1630
#                               collapse-layer-x equivalent     1286     1254
#                                                none           1368     1630
#                               none             equivalent     1286     1254
#                                                none           1368     1630
#
# domain                                                       rovers  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent     21020
#                                                none           21036
#                               collapse-layer   equivalent     21020
#                                                none           21036
#                               collapse-layer-x equivalent     21020
#                                                none           21036
#                               none             equivalent     21020
#                                                none           21036
#                    4          collapse-all     equivalent         0
#                                                none               0
#                               collapse-layer   equivalent     21020
#                                                none           21036
#                               collapse-layer-x equivalent     21020
#                                                none           21036
#                               none             equivalent         0
#                                                none               0
#                    6          collapse-all     equivalent         0
#                                                none               0
#                               collapse-layer   equivalent     21020
#                                                none           21036
#                               collapse-layer-x equivalent     21020
#                                                none           21036
#                               none             equivalent         0
#                                                none               0
# svr       wl       2          collapse-all     equivalent      1420
#                                                none            1428
#                               collapse-layer   equivalent      1420
#                                                none            1428
#                               collapse-layer-x equivalent      1420
#                                                none            1428
#                               none             equivalent      1420
#                                                none            1428
#                    4          collapse-all     equivalent      1420
#                                                none            1428
#                               collapse-layer   equivalent      1420
#                                                none            1428
#                               collapse-layer-x equivalent      1420
#                                                none            1428
#                               none             equivalent      1420
#                                                none            1428
#                    6          collapse-all     equivalent      1420
#                                                none            1428
#                               collapse-layer   equivalent      1420
#                                                none            1428
#                               collapse-layer-x equivalent      1420
#                                                none            1428
#                               none             equivalent      1420
#                                                none            1428
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent        65277
#                                                none              65312
#                               collapse-layer   equivalent        65277
#                                                none              65312
#                               collapse-layer-x equivalent        65277
#                                                none              65312
#                               none             equivalent        65277
#                                                none              65312
#                    4          collapse-all     equivalent            0
#                                                none                  0
#                               collapse-layer   equivalent            0
#                                                none                  0
#                               collapse-layer-x equivalent        65277
#                                                none              65312
#                               none             equivalent            0
#                                                none                  0
#                    6          collapse-all     equivalent            0
#                                                none                  0
#                               collapse-layer   equivalent            0
#                                                none                  0
#                               collapse-layer-x equivalent        65277
#                                                none              65312
#                               none             equivalent            0
#                                                none                  0
# svr       wl       2          collapse-all     equivalent         1150
#                                                none               1158
#                               collapse-layer   equivalent         1150
#                                                none               1158
#                               collapse-layer-x equivalent         1150
#                                                none               1158
#                               none             equivalent         1150
#                                                none               1158
#                    4          collapse-all     equivalent         1150
#                                                none               1158
#                               collapse-layer   equivalent         1150
#                                                none               1158
#                               collapse-layer-x equivalent         1150
#                                                none               1158
#                               none             equivalent         1150
#                                                none               1158
#                    6          collapse-all     equivalent         1150
#                                                none               1158
#                               collapse-layer   equivalent         1150
#                                                none               1158
#                               collapse-layer-x equivalent         1150
#                                                none               1158
#                               none             equivalent         1150
#                                                none               1158
#
# domain                                                       spanner  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent       2499
#                                                none             4576
#                               collapse-layer   equivalent       2499
#                                                none             4576
#                               collapse-layer-x equivalent       2499
#                                                none             4576
#                               none             equivalent       2499
#                                                none             4576
#                    4          collapse-all     equivalent       2499
#                                                none             4576
#                               collapse-layer   equivalent       2499
#                                                none             4576
#                               collapse-layer-x equivalent       2499
#                                                none             4576
#                               none             equivalent       2499
#                                                none             4576
#                    6          collapse-all     equivalent       2499
#                                                none             4576
#                               collapse-layer   equivalent       2499
#                                                none             4576
#                               collapse-layer-x equivalent       2499
#                                                none             4576
#                               none             equivalent       2499
#                                                none             4576
# svr       wl       2          collapse-all     equivalent        820
#                                                none             1204
#                               collapse-layer   equivalent        820
#                                                none             1204
#                               collapse-layer-x equivalent        765
#                                                none             1204
#                               none             equivalent        820
#                                                none             1204
#                    4          collapse-all     equivalent        820
#                                                none             1204
#                               collapse-layer   equivalent        820
#                                                none             1204
#                               collapse-layer-x equivalent        765
#                                                none             1204
#                               none             equivalent        820
#                                                none             1204
#                    6          collapse-all     equivalent        820
#                                                none             1204
#                               collapse-layer   equivalent        820
#                                                none             1204
#                               collapse-layer-x equivalent        765
#                                                none             1204
#                               none             equivalent        820
#                                                none             1204
#
# domain                                                       transport
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent        14984
#                                                none              15013
#                               collapse-layer   equivalent        14984
#                                                none              15013
#                               collapse-layer-x equivalent        14984
#                                                none              15013
#                               none             equivalent        14984
#                                                none              15013
#                    4          collapse-all     equivalent        14984
#                                                none              15013
#                               collapse-layer   equivalent        14984
#                                                none              15013
#                               collapse-layer-x equivalent        14984
#                                                none              15013
#                               none             equivalent        14984
#                                                none              15013
#                    6          collapse-all     equivalent            0
#                                                none                  0
#                               collapse-layer   equivalent        14984
#                                                none              15013
#                               collapse-layer-x equivalent        14984
#                                                none              15013
#                               none             equivalent            0
#                                                none                  0
# svr       wl       2          collapse-all     equivalent          724
#                                                none                735
#                               collapse-layer   equivalent          724
#                                                none                735
#                               collapse-layer-x equivalent          718
#                                                none                735
#                               none             equivalent          724
#                                                none                735
#                    4          collapse-all     equivalent          724
#                                                none                735
#                               collapse-layer   equivalent          724
#                                                none                735
#                               collapse-layer-x equivalent          718
#                                                none                735
#                               none             equivalent          724
#                                                none                735
#                    6          collapse-all     equivalent          724
#                                                none                735
#                               collapse-layer   equivalent          724
#                                                none                735
#                               collapse-layer-x equivalent          718
#                                                none                735
#                               none             equivalent          724
#                                                none                735
# n_colours
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent            349
#                                                none                  349
#                               collapse-layer   equivalent            320
#                                                none                  320
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent            358
#                                                none                  358
#                    4          collapse-all     equivalent          13273
#                                                none                13273
#                               collapse-layer   equivalent           3577
#                                                none                 3577
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent          22836
#                                                none                22836
#                    6          collapse-all     equivalent          24619
#                                                none                24619
#                               collapse-layer   equivalent           4390
#                                                none                 4390
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent              0
#                                                none                    0
# svr       wl       2          collapse-all     equivalent            339
#                                                none                  339
#                               collapse-layer   equivalent            310
#                                                none                  310
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent            348
#                                                none                  348
#                    4          collapse-all     equivalent           4514
#                                                none                 4514
#                               collapse-layer   equivalent           1771
#                                                none                 1771
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent          10445
#                                                none                10445
#                    6          collapse-all     equivalent           5181
#                                                none                 5181
#                               collapse-layer   equivalent           1941
#                                                none                 1941
#                               collapse-layer-x equivalent             41
#                                                none                   41
#                               none             equivalent          41816
#                                                none                41816
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent            56
#                                                none                  56
#                               collapse-layer   equivalent            61
#                                                none                  61
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent            86
#                                                none                  86
#                    4          collapse-all     equivalent           156
#                                                none                 156
#                               collapse-layer   equivalent            96
#                                                none                  96
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent           263
#                                                none                 263
#                    6          collapse-all     equivalent           115
#                                                none                 115
#                               collapse-layer   equivalent           102
#                                                none                 102
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent           525
#                                                none                 525
# svr       wl       2          collapse-all     equivalent            56
#                                                none                  56
#                               collapse-layer   equivalent            61
#                                                none                  61
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent            86
#                                                none                  86
#                    4          collapse-all     equivalent           126
#                                                none                 126
#                               collapse-layer   equivalent            86
#                                                none                  86
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent           255
#                                                none                 255
#                    6          collapse-all     equivalent            85
#                                                none                  85
#                               collapse-layer   equivalent            88
#                                                none                  88
#                               collapse-layer-x equivalent            24
#                                                none                  24
#                               none             equivalent           490
#                                                none                 490
#
# domain                                                       ferry  miconic  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent      334       30
#                                                none            334       30
#                               collapse-layer   equivalent      207       26
#                                                none            207       26
#                               collapse-layer-x equivalent       79       14
#                                                none             79       14
#                               none             equivalent      373       47
#                                                none            373       47
#                    4          collapse-all     equivalent     3004       20
#                                                none           3004       20
#                               collapse-layer   equivalent      217       28
#                                                none            217       28
#                               collapse-layer-x equivalent       79       14
#                                                none             79       14
#                               none             equivalent     4398      112
#                                                none           4398      112
#                    6          collapse-all     equivalent    14952       20
#                                                none          14952       20
#                               collapse-layer   equivalent      221       30
#                                                none            221       30
#                               collapse-layer-x equivalent       79       14
#                                                none             79       14
#                               none             equivalent    25515      182
#                                                none          25515      182
# svr       wl       2          collapse-all     equivalent      314       30
#                                                none            314       30
#                               collapse-layer   equivalent      193       26
#                                                none            193       26
#                               collapse-layer-x equivalent       73       14
#                                                none             73       14
#                               none             equivalent      346       47
#                                                none            346       47
#                    4          collapse-all     equivalent     1965       20
#                                                none           1965       20
#                               collapse-layer   equivalent      203       28
#                                                none            203       28
#                               collapse-layer-x equivalent       73       14
#                                                none             73       14
#                               none             equivalent     3232      112
#                                                none           3232      112
#                    6          collapse-all     equivalent     6690       20
#                                                none           6690       20
#                               collapse-layer   equivalent      207       30
#                                                none            207       30
#                               collapse-layer-x equivalent       73       14
#                                                none             73       14
#                               none             equivalent    13586      182
#                                                none          13586      182
#
# domain                                                       rovers  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent      5381
#                                                none            5381
#                               collapse-layer   equivalent      4984
#                                                none            4984
#                               collapse-layer-x equivalent       363
#                                                none             363
#                               none             equivalent      6729
#                                                none            6729
#                    4          collapse-all     equivalent         0
#                                                none               0
#                               collapse-layer   equivalent     13947
#                                                none           13947
#                               collapse-layer-x equivalent       363
#                                                none             363
#                               none             equivalent         0
#                                                none               0
#                    6          collapse-all     equivalent         0
#                                                none               0
#                               collapse-layer   equivalent     14360
#                                                none           14360
#                               collapse-layer-x equivalent       363
#                                                none             363
#                               none             equivalent         0
#                                                none               0
# svr       wl       2          collapse-all     equivalent      2386
#                                                none            2386
#                               collapse-layer   equivalent      2158
#                                                none            2158
#                               collapse-layer-x equivalent       279
#                                                none             279
#                               none             equivalent      3404
#                                                none            3404
#                    4          collapse-all     equivalent      8009
#                                                none            8009
#                               collapse-layer   equivalent      4583
#                                                none            4583
#                               collapse-layer-x equivalent       279
#                                                none             279
#                               none             equivalent     23206
#                                                none           23206
#                    6          collapse-all     equivalent      6993
#                                                none            6993
#                               collapse-layer   equivalent      4665
#                                                none            4665
#                               collapse-layer-x equivalent       279
#                                                none             279
#                               none             equivalent     56799
#                                                none           56799
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent         3998
#                                                none               3998
#                               collapse-layer   equivalent         3896
#                                                none               3896
#                               collapse-layer-x equivalent          292
#                                                none                292
#                               none             equivalent         4265
#                                                none               4265
#                    4          collapse-all     equivalent            0
#                                                none                  0
#                               collapse-layer   equivalent            0
#                                                none                  0
#                               collapse-layer-x equivalent          292
#                                                none                292
#                               none             equivalent            0
#                                                none                  0
#                    6          collapse-all     equivalent            0
#                                                none                  0
#                               collapse-layer   equivalent            0
#                                                none                  0
#                               collapse-layer-x equivalent          292
#                                                none                292
#                               none             equivalent            0
#                                                none                  0
# svr       wl       2          collapse-all     equivalent         1846
#                                                none               1846
#                               collapse-layer   equivalent         1773
#                                                none               1773
#                               collapse-layer-x equivalent          213
#                                                none                213
#                               none             equivalent         2231
#                                                none               2231
#                    4          collapse-all     equivalent         9178
#                                                none               9178
#                               collapse-layer   equivalent         5938
#                                                none               5938
#                               collapse-layer-x equivalent          213
#                                                none                213
#                               none             equivalent        22159
#                                                none              22159
#                    6          collapse-all     equivalent        14157
#                                                none              14157
#                               collapse-layer   equivalent         6128
#                                                none               6128
#                               collapse-layer-x equivalent          213
#                                                none                213
#                               none             equivalent        63084
#                                                none              63084
#
# domain                                                       spanner  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     equivalent         78
#                                                none               78
#                               collapse-layer   equivalent         67
#                                                none               67
#                               collapse-layer-x equivalent         21
#                                                none               21
#                               none             equivalent         86
#                                                none               86
#                    4          collapse-all     equivalent        295
#                                                none              295
#                               collapse-layer   equivalent        106
#                                                none              106
#                               collapse-layer-x equivalent         21
#                                                none               21
#                               none             equivalent        378
#                                                none              378
#                    6          collapse-all     equivalent        159
#                                                none              159
#                               collapse-layer   equivalent        108
#                                                none              108
#                               collapse-layer-x equivalent         21
#                                                none               21
#                               none             equivalent        877
#                                                none              877
# svr       wl       2          collapse-all     equivalent         77
#                                                none               77
#                               collapse-layer   equivalent         66
#                                                none               66
#                               collapse-layer-x equivalent         21
#                                                none               21
#                               none             equivalent         85
#                                                none               85
#                    4          collapse-all     equivalent        273
#                                                none              273
#                               collapse-layer   equivalent        103
#                                                none              103
#                               collapse-layer-x equivalent         21
#                                                none               21
#                               none             equivalent        354
#                                                none              354
#                    6          collapse-all     equivalent        144
#                                                none              144
# ...
#                    6          collapse-all     equivalent     0.043231
#                                                none           0.036001
#                               collapse-layer   equivalent     0.097168
#                                                none           0.100067
#                               collapse-layer-x equivalent     1.767959
#                                                none           2.080684
#                               none             equivalent     0.030489
#                                                none           0.032594
# f1_macro
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent       0.619927
#                                                none             0.622186
#                               collapse-layer   equivalent       0.618337
#                                                none             0.622305
#                               collapse-layer-x equivalent       0.190532
#                                                none             0.263711
#                               none             equivalent       0.625315
#                                                none             0.621567
#                    4          collapse-all     equivalent       1.000000
#                                                none             1.000000
#                               collapse-layer   equivalent       0.952262
#                                                none             0.952579
#                               collapse-layer-x equivalent       0.190532
#                                                none             0.263711
#                               none             equivalent       1.000000
#                                                none             1.000000
#                    6          collapse-all     equivalent       1.000000
#                                                none             1.000000
#                               collapse-layer   equivalent       0.940493
#                                                none             0.940083
#                               collapse-layer-x equivalent       0.190532
#                                                none             0.263711
#                               none             equivalent       1.000000
#                                                none             1.000000
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent      0.293739
#                                                none            0.209459
#                               collapse-layer   equivalent      0.331194
#                                                none            0.257630
#                               collapse-layer-x equivalent      0.266263
#                                                none            0.278336
#                               none             equivalent      0.319985
#                                                none            0.252132
#                    4          collapse-all     equivalent      0.267239
#                                                none            0.204988
#                               collapse-layer   equivalent      0.292476
#                                                none            0.249039
#                               collapse-layer-x equivalent      0.266263
#                                                none            0.278336
#                               none             equivalent      0.321665
#                                                none            0.263305
#                    6          collapse-all     equivalent      0.268624
#                                                none            0.204653
#                               collapse-layer   equivalent      0.316613
#                                                none            0.245798
#                               collapse-layer-x equivalent      0.266263
#                                                none            0.278336
#                               none             equivalent      0.282784
#                                                none            0.332664
#
# domain                                                          ferry  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent    0.904545
#                                                none          0.904542
#                               collapse-layer   equivalent    0.904545
#                                                none          0.904542
#                               collapse-layer-x equivalent    0.768018
#                                                none          0.771552
#                               none             equivalent    0.904545
#                                                none          0.904542
#                    4          collapse-all     equivalent    0.948518
#                                                none          0.948551
#                               collapse-layer   equivalent    0.904545
#                                                none          0.904542
#                               collapse-layer-x equivalent    0.768018
#                                                none          0.771552
#                               none             equivalent    0.948518
#                                                none          0.949564
#                    6          collapse-all     equivalent    0.976121
#                                                none          0.976142
#                               collapse-layer   equivalent    0.904545
#                                                none          0.904542
#                               collapse-layer-x equivalent    0.768018
#                                                none          0.771552
#                               none             equivalent    0.976121
#                                                none          0.976142
#
# domain                                                        miconic  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent    0.345924
#                                                none          0.366664
#                               collapse-layer   equivalent    0.348235
#                                                none          0.352895
#                               collapse-layer-x equivalent    0.327143
#                                                none          0.344281
#                               none             equivalent    0.334390
#                                                none          0.348837
#                    4          collapse-all     equivalent    0.346703
#                                                none          0.351767
#                               collapse-layer   equivalent    0.345234
#                                                none          0.352187
#                               collapse-layer-x equivalent    0.327143
#                                                none          0.344281
#                               none             equivalent    0.356835
#                                                none          0.359890
#                    6          collapse-all     equivalent    0.346703
#                                                none          0.351767
#                               collapse-layer   equivalent    0.333471
#                                                none          0.357697
#                               collapse-layer-x equivalent    0.327143
#                                                none          0.344281
#                               none             equivalent    0.356719
#                                                none          0.383493
#
# domain                                                         rovers  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent    0.783419
#                                                none          0.783958
#                               collapse-layer   equivalent    0.785729
#                                                none          0.784829
#                               collapse-layer-x equivalent    0.520051
#                                                none          0.519659
#                               none             equivalent    0.783158
#                                                none          0.787643
#                    4          collapse-all     equivalent    0.899891
#                                                none          0.900707
#                               collapse-layer   equivalent    0.899040
#                                                none          0.898595
#                               collapse-layer-x equivalent    0.520051
#                                                none          0.519659
#                               none             equivalent    0.895218
#                                                none          0.894678
#                    6          collapse-all     equivalent    0.878784
#                                                none          0.881612
#                               collapse-layer   equivalent    0.897481
#                                                none          0.896586
#                               collapse-layer-x equivalent    0.520051
#                                                none          0.519659
#                               none             equivalent    0.882866
#                                                none          0.891806
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent     0.000000
#                                                none           0.000000
#                               collapse-layer   equivalent     0.000000
#                                                none           0.000000
#                               collapse-layer-x equivalent     0.001242
#                                                none           0.002064
#                               none             equivalent     0.000000
#                                                none           0.000000
#                    4          collapse-all     equivalent     0.000000
#                                                none           0.000000
#                               collapse-layer   equivalent     0.000288
#                                                none           0.000283
#                               collapse-layer-x equivalent     0.001242
#                                                none           0.002064
#                               none             equivalent     0.000317
#                                                none           0.000285
#                    6          collapse-all     equivalent     0.000000
#                                                none           0.000000
#                               collapse-layer   equivalent     0.000288
#                                                none           0.000282
#                               collapse-layer-x equivalent     0.001242
#                                                none           0.002064
#                               none             equivalent     0.000307
#                                                none           0.000000
#
# domain                                                        spanner  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent    0.237847
#                                                none          0.179302
#                               collapse-layer   equivalent    0.214475
#                                                none          0.161520
#                               collapse-layer-x equivalent    0.190343
#                                                none          0.208184
#                               none             equivalent    0.267331
#                                                none          0.261382
#                    4          collapse-all     equivalent    0.275875
#                                                none          0.301570
#                               collapse-layer   equivalent    0.257351
#                                                none          0.288699
#                               collapse-layer-x equivalent    0.190343
#                                                none          0.208184
#                               none             equivalent    0.277246
#                                                none          0.299427
#                    6          collapse-all     equivalent    0.272032
#                                                none          0.301570
#                               collapse-layer   equivalent    0.269985
#                                                none          0.288743
#                               collapse-layer-x equivalent    0.190343
#                                                none          0.208184
#                               none             equivalent    0.279876
#                                                none          0.300668
#
# domain                                                       transport
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     equivalent     0.478997
#                                                none           0.507539
#                               collapse-layer   equivalent     0.490517
#                                                none           0.500789
#                               collapse-layer-x equivalent     0.244298
#                                                none           0.214170
#                               none             equivalent     0.494960
#                                                none           0.504410
#                    4          collapse-all     equivalent     0.921256
#                                                none           0.924085
#                               collapse-layer   equivalent     0.912515
#                                                none           0.906617
#                               collapse-layer-x equivalent     0.244298
#                                                none           0.214170
#                               none             equivalent     0.922049
#                                                none           0.921788
#                    6          collapse-all     equivalent     0.980246
#                                                none           0.981395
#                               collapse-layer   equivalent     0.935276
#                                                none           0.934695
#                               collapse-layer-x equivalent     0.244298
#                                                none           0.214170
#                               none             equivalent     0.978417
#                                                none           0.980633
