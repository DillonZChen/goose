# %%
from data.helper import *

# %%
DF = get_train_df()
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 4974.76it/s]

# %%
for metric in ["n_colours", "mse_loss", "f1_macro"]:
    print(metric)
    df = DF.copy()
    df = df[df.iterations == "4"]
    df = df[df.completed]
    df = df[df["optimiser"].isin({"svr", "rank-svm"})]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(["pruning", "optimiser", "domain"]).max().reset_index()
    df = df[["pruning", "optimiser", "domain", metric]]
    # pivot table
    df = df.pivot_table(index=["optimiser", "pruning"], values=metric, columns="domain")
    # make entries int2
    if metric == "n_colours":
        df = df.fillna(0)
        df = df.astype(int)
    display(df)
# Out:
# n_colours
# domain                    blocksworld  childsnack  ferry  floortile  miconic  \
# optimiser pruning
# rank-svm  collapse-all          10506         123   2373      13380       20
#           collapse-layer         3577          96    217       2262       28
#           none                  22835         259   4394          0      108
# svr       collapse-all           3218         105   1507       5444       20
#           collapse-layer         1771          86    203        757       28
#           none                  10444         251   3228       7616      108
#
# domain                    rovers  satellite  sokoban  spanner  transport
# optimiser pruning
# rank-svm  collapse-all     18808          0       27      208       6545
#           collapse-layer   13947          0       30      106       3129
#           none                 0          0      114      374       8932
# svr       collapse-all      4529       5232       22      189       2255
#           collapse-layer    4583       5938       30      103       1295
#           none             23202      22155      110      350       3787
# mse_loss
# domain                    blocksworld  childsnack     ferry  floortile  \
# optimiser pruning
# rank-svm  collapse-all      -1.000000   -1.000000 -1.000000  -1.000000
#           collapse-layer    -1.000000   -1.000000 -1.000000  -1.000000
#           none              -1.000000   -1.000000 -1.000000        NaN
# svr       collapse-all       0.000421    1.308301  0.049911   0.646432
#           collapse-layer     0.091440    0.862840  0.100699   0.803673
#           none               0.002113    0.544423  0.042738   0.647230
#
# domain                     miconic    rovers  satellite    sokoban   spanner  \
# optimiser pruning
# rank-svm  collapse-all   -1.000000 -1.000000        NaN  -1.000000 -1.000000
#           collapse-layer -1.000000 -1.000000        NaN  -1.000000 -1.000000
#           none           -1.000000       NaN        NaN  -1.000000 -1.000000
# svr       collapse-all    0.763184  0.201610   2.678003  67.467223  1.662510
#           collapse-layer  0.769398  0.186038   3.351806  52.498732  1.700438
#           none            0.761528  0.212367   2.876319  88.929085  1.687171
#
# domain                    transport
# optimiser pruning
# rank-svm  collapse-all    -1.000000
#           collapse-layer  -1.000000
#           none            -1.000000
# svr       collapse-all     0.084458
#           collapse-layer   0.129761
#           none             0.088406
# f1_macro
# domain                    blocksworld  childsnack     ferry  floortile  \
# optimiser pruning
# rank-svm  collapse-all      -1.000000   -1.000000 -1.000000  -1.000000
#           collapse-layer    -1.000000   -1.000000 -1.000000  -1.000000
#           none              -1.000000   -1.000000 -1.000000        NaN
# svr       collapse-all       1.000000    0.204988  0.948551   0.647532
#           collapse-layer     0.952579    0.249039  0.904542   0.479013
#           none               1.000000    0.413739  0.950482   0.649611
#
# domain                     miconic    rovers  satellite   sokoban   spanner  \
# optimiser pruning
# rank-svm  collapse-all   -1.000000 -1.000000        NaN -1.000000 -1.000000
#           collapse-layer -1.000000 -1.000000        NaN -1.000000 -1.000000
#           none           -1.000000       NaN        NaN -1.000000 -1.000000
# svr       collapse-all    0.351767  0.902183   0.000283  0.013068  0.302128
#           collapse-layer  0.352187  0.898595   0.000283  0.021333  0.288699
#           none            0.367464  0.893467   0.000000  0.017670  0.296936
#
# domain                    transport
# optimiser pruning
# rank-svm  collapse-all    -1.000000
#           collapse-layer  -1.000000
#           none            -1.000000
# svr       collapse-all     0.923425
#           collapse-layer   0.906617
#           none             0.924961

# %%
for domain in DOMAINS:
    df = DF.copy()
    print(domain)
    df = df[df["domain"] == domain]
    df = df[df["optimiser"].isin({"svr", "rank-svm"})]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(["pruning", "optimiser"]).max().reset_index()
    df = df[["pruning", "optimiser", "n_data"]]
    # pivot table
    df = df.pivot_table(index=["pruning", "optimiser"], values="n_data")
    # make entries int2
    df = df.astype(int)
    df = df.fillna(0)
    display(df)
# Out:
# blocksworld
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm     7703
#                svr          1292
# collapse-layer rank-svm     7703
#                svr          1292
# none           rank-svm     7703
#                svr          1292
# childsnack
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    10334
#                svr           473
# collapse-layer rank-svm    10334
#                svr           473
# none           rank-svm    10334
#                svr           473
# ferry
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    13719
#                svr          1368
# collapse-layer rank-svm    13719
#                svr          1368
# none           rank-svm    13719
#                svr          1368
# floortile
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    32549
#                svr          3187
# collapse-layer rank-svm    32549
#                svr          3187
# none           rank-svm       -1
#                svr          3187
# miconic
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    24089
#                svr          1630
# collapse-layer rank-svm    24089
#                svr          1630
# none           rank-svm    24089
#                svr          1630
# rovers
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    21036
#                svr          1428
# collapse-layer rank-svm    21036
#                svr          1428
# none           rank-svm       -1
#                svr          1428
# satellite
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm       -1
#                svr          1158
# collapse-layer rank-svm       -1
#                svr          1158
# none           rank-svm       -1
#                svr          1158
# sokoban
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    10406
#                svr          2422
# collapse-layer rank-svm    10406
#                svr          2422
# none           rank-svm    10406
#                svr          2422
# spanner
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm     4576
#                svr          1204
# collapse-layer rank-svm     4576
#                svr          1204
# none           rank-svm     4576
#                svr          1204
# transport
#                           n_data
# pruning        optimiser
# collapse-all   rank-svm    15013
#                svr           735
# collapse-layer rank-svm    15013
#                svr           735
# none           rank-svm    15013
#                svr           735

# %%
for domain in DOMAINS:
    df = DF.copy()
    print(domain)
    df = df[df["domain"] == domain]
    df = df[df["optimiser"].isin({"svr", "rank-svm"})]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(["pruning", "optimiser", "iterations"]).max().reset_index()
    df = df[["pruning", "optimiser", "iterations", "n_colours"]]
    # pivot table
    df = df.pivot_table(index=["pruning", "optimiser"], columns="iterations", values="n_colours")
    # make entries int
    df = df.astype(int)
    df = df.fillna(0)
    display(df)
# Out:
# blocksworld
# iterations                    4
# pruning        optimiser
# collapse-all   rank-svm   10506
#                svr         3218
# collapse-layer rank-svm    3577
#                svr         1771
# none           rank-svm   22835
#                svr        10444
# childsnack
# iterations                  4
# pruning        optimiser
# collapse-all   rank-svm   123
#                svr        105
# collapse-layer rank-svm    96
#                svr         86
# none           rank-svm   259
#                svr        251
# ferry
# iterations                   4
# pruning        optimiser
# collapse-all   rank-svm   2373
#                svr        1507
# collapse-layer rank-svm    217
#                svr         203
# none           rank-svm   4394
#                svr        3228
# floortile
# iterations                    4
# pruning        optimiser
# collapse-all   rank-svm   13380
#                svr         5444
# collapse-layer rank-svm    2262
#                svr          757
# none           rank-svm      -1
#                svr         7616
# miconic
# iterations                  4
# pruning        optimiser
# collapse-all   rank-svm    20
#                svr         20
# collapse-layer rank-svm    28
#                svr         28
# none           rank-svm   108
#                svr        108
# rovers
# iterations                    4
# pruning        optimiser
# collapse-all   rank-svm   18808
#                svr         4529
# collapse-layer rank-svm   13947
#                svr         4583
# none           rank-svm      -1
#                svr        23202
# satellite
# iterations                    4
# pruning        optimiser
# collapse-all   rank-svm      -1
#                svr         5232
# collapse-layer rank-svm      -1
#                svr         5938
# none           rank-svm      -1
#                svr        22155
# sokoban
# iterations                  4
# pruning        optimiser
# collapse-all   rank-svm    27
#                svr         22
# collapse-layer rank-svm    30
#                svr         30
# none           rank-svm   114
#                svr        110
# spanner
# iterations                  4
# pruning        optimiser
# collapse-all   rank-svm   208
#                svr        189
# collapse-layer rank-svm   106
#                svr        103
# none           rank-svm   374
#                svr        350
# transport
# iterations                   4
# pruning        optimiser
# collapse-all   rank-svm   6545
#                svr        2255
# collapse-layer rank-svm   3129
#                svr        1295
# none           rank-svm   8932
#                svr        3787
