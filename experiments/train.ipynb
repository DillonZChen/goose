# %%
from data.helper import *

# %%
DF = get_train_df()
# Out:
# 100%|██████████| 1536/1536 [00:00<00:00, 3192.06it/s]

# %%
COLUMNS = [
    "optimiser",
    "features",
    "iterations",
    "feature_pruning",
    "data_pruning",
]

# %%
for metric in [
    # "n_data",
    "n_colours",
    "mse_loss",
    "f1_macro",
]:
    print(metric)
    df = DF.copy()
    df = df[df.facts == "fd"]
    df = df[df.features == "wl"]
    df = df[df.data_pruning == "none"]
    # df = df[df.completed]
    Models = {"svr"}
    if metric in {"n_colours", "n_data"}:
        Models.add("rank-svm")
    df = df[df["optimiser"].isin(Models)]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(COLUMNS + ["domain"]).max().reset_index()
    df = df[COLUMNS + ["domain", metric]]
    # pivot table
    df = df.pivot_table(index=COLUMNS, values=metric, columns="domain")
    # make entries int2
    if metric in {"n_colours", "n_data"}:
        df = df.fillna(0)
        df = df.astype(int)
    # display(df)
    # display df without hiding rows
    with pd.option_context("display.max_rows", None):
        display(df)
# Out:
# n_colours
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none                  349
#                               collapse-layer   none                  320
#                               collapse-layer-x none                   41
#                               none             none                  358
#                    4          collapse-all     none                13273
#                               collapse-layer   none                 3577
#                               collapse-layer-x none                   41
#                               none             none                22836
#                    6          collapse-all     none                24619
#                               collapse-layer   none                 4390
#                               collapse-layer-x none                   41
#                               none             none                   -1
# svr       wl       2          collapse-all     none                  339
#                               collapse-layer   none                  310
#                               collapse-layer-x none                   41
#                               none             none                  348
#                    4          collapse-all     none                 4514
#                               collapse-layer   none                 1771
#                               collapse-layer-x none                   41
#                               none             none                10445
#                    6          collapse-all     none                 5181
#                               collapse-layer   none                 1941
#                               collapse-layer-x none                   41
#                               none             none                41816
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none                  56
#                               collapse-layer   none                  61
#                               collapse-layer-x none                  24
#                               none             none                  86
#                    4          collapse-all     none                 156
#                               collapse-layer   none                  96
#                               collapse-layer-x none                  24
#                               none             none                 263
#                    6          collapse-all     none                 115
#                               collapse-layer   none                 102
#                               collapse-layer-x none                  24
#                               none             none                 525
# svr       wl       2          collapse-all     none                  56
#                               collapse-layer   none                  61
#                               collapse-layer-x none                  24
#                               none             none                  86
#                    4          collapse-all     none                 126
#                               collapse-layer   none                  86
#                               collapse-layer-x none                  24
#                               none             none                 255
#                    6          collapse-all     none                  85
#                               collapse-layer   none                  88
#                               collapse-layer-x none                  24
#                               none             none                 490
#
# domain                                                       ferry  miconic  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none            334       30
#                               collapse-layer   none            207       26
#                               collapse-layer-x none             79       14
#                               none             none            373       47
#                    4          collapse-all     none           3004       20
#                               collapse-layer   none            217       28
#                               collapse-layer-x none             79       14
#                               none             none           4398      112
#                    6          collapse-all     none          14952       20
#                               collapse-layer   none            221       30
#                               collapse-layer-x none             79       14
#                               none             none          25515      182
# svr       wl       2          collapse-all     none            314       30
#                               collapse-layer   none            193       26
#                               collapse-layer-x none             73       14
#                               none             none            346       47
#                    4          collapse-all     none           1965       20
#                               collapse-layer   none            203       28
#                               collapse-layer-x none             73       14
#                               none             none           3232      112
#                    6          collapse-all     none           6690       20
#                               collapse-layer   none            207       30
#                               collapse-layer-x none             73       14
#                               none             none          13586      182
#
# domain                                                       rovers  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none            5381
#                               collapse-layer   none            4984
#                               collapse-layer-x none             363
#                               none             none            6729
#                    4          collapse-all     none              -1
#                               collapse-layer   none           13947
#                               collapse-layer-x none             363
#                               none             none              -1
#                    6          collapse-all     none              -1
#                               collapse-layer   none           14360
#                               collapse-layer-x none             363
#                               none             none              -1
# svr       wl       2          collapse-all     none            2386
#                               collapse-layer   none            2158
#                               collapse-layer-x none             279
#                               none             none            3404
#                    4          collapse-all     none            8009
#                               collapse-layer   none            4583
#                               collapse-layer-x none             279
#                               none             none           23206
#                    6          collapse-all     none            6993
#                               collapse-layer   none            4665
#                               collapse-layer-x none             279
#                               none             none           56799
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none               3998
#                               collapse-layer   none               3896
#                               collapse-layer-x none                292
#                               none             none               4265
#                    4          collapse-all     none                 -1
#                               collapse-layer   none                 -1
#                               collapse-layer-x none                292
#                               none             none                 -1
#                    6          collapse-all     none                 -1
#                               collapse-layer   none                 -1
#                               collapse-layer-x none                292
#                               none             none                 -1
# svr       wl       2          collapse-all     none               1846
#                               collapse-layer   none               1773
#                               collapse-layer-x none                213
#                               none             none               2231
#                    4          collapse-all     none               9178
#                               collapse-layer   none               5938
#                               collapse-layer-x none                213
#                               none             none              22159
#                    6          collapse-all     none              14157
#                               collapse-layer   none               6128
#                               collapse-layer-x none                213
#                               none             none              63084
#
# domain                                                       spanner  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none               78
#                               collapse-layer   none               67
#                               collapse-layer-x none               21
#                               none             none               86
#                    4          collapse-all     none              295
#                               collapse-layer   none              106
#                               collapse-layer-x none               21
#                               none             none              378
#                    6          collapse-all     none              159
#                               collapse-layer   none              108
#                               collapse-layer-x none               21
#                               none             none              877
# svr       wl       2          collapse-all     none               77
#                               collapse-layer   none               66
#                               collapse-layer-x none               21
#                               none             none               85
#                    4          collapse-all     none              273
#                               collapse-layer   none              103
#                               collapse-layer-x none               21
#                               none             none              354
#                    6          collapse-all     none              144
#                               collapse-layer   none              105
#                               collapse-layer-x none               21
#                               none             none              803
#
# domain                                                       transport
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  wl       2          collapse-all     none                459
#                               collapse-layer   none                375
#                               collapse-layer-x none                 78
#                               none             none                465
#                    4          collapse-all     none               7395
#                               collapse-layer   none               3129
#                               collapse-layer-x none                 78
#                               none             none               8936
#                    6          collapse-all     none                 -1
#                               collapse-layer   none              10416
#                               collapse-layer-x none                 78
#                               none             none                 -1
# svr       wl       2          collapse-all     none                324
#                               collapse-layer   none                257
#                               collapse-layer-x none                 60
#                               none             none                331
#                    4          collapse-all     none               2728
#                               collapse-layer   none               1295
#                               collapse-layer-x none                 60
#                               none             none               3791
#                    6          collapse-all     none               7406
#                               collapse-layer   none               2405
#                               collapse-layer-x none                 60
#                               none             none              16833
# mse_loss
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none             0.511840
#                               collapse-layer   none             0.509068
#                               collapse-layer-x none             3.987980
#                               none             none             0.507346
#                    4          collapse-all     none             0.000668
#                               collapse-layer   none             0.091440
#                               collapse-layer-x none             3.987980
#                               none             none             0.004935
#                    6          collapse-all     none             0.000119
#                               collapse-layer   none             0.091904
#                               collapse-layer-x none             3.987980
#                               none             none             0.005773
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none            1.143180
#                               collapse-layer   none            0.815809
#                               collapse-layer-x none            0.704940
#                               none             none            0.711446
#                    4          collapse-all     none            1.304229
#                               collapse-layer   none            0.862840
#                               collapse-layer-x none            0.704940
#                               none             none            0.574822
#                    6          collapse-all     none            1.262780
#                               collapse-layer   none            0.831017
#                               collapse-layer-x none            0.704940
#                               none             none            0.542184
#
# domain                                                          ferry  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.085349
#                               collapse-layer   none          0.100333
#                               collapse-layer-x none          0.197528
#                               none             none          0.081969
#                    4          collapse-all     none          0.047422
#                               collapse-layer   none          0.100699
#                               collapse-layer-x none          0.197528
#                               none             none          0.044637
#                    6          collapse-all     none          0.029879
#                               collapse-layer   none          0.100682
#                               collapse-layer-x none          0.197528
#                               none             none          0.026087
#
# domain                                                        miconic  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.767342
#                               collapse-layer   none          0.766507
#                               collapse-layer-x none          0.784374
#                               none             none          0.763411
#                    4          collapse-all     none          0.763184
#                               collapse-layer   none          0.769398
#                               collapse-layer-x none          0.784374
#                               none             none          0.761053
#                    6          collapse-all     none          0.763184
#                               collapse-layer   none          0.766712
#                               collapse-layer-x none          0.784374
#                               none             none          0.792502
#
# domain                                                         rovers  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.428273
#                               collapse-layer   none          0.433503
#                               collapse-layer-x none          1.006485
#                               none             none          0.447003
#                    4          collapse-all     none          0.208698
#                               collapse-layer   none          0.186038
#                               collapse-layer-x none          1.006485
#                               none             none          0.230729
#                    6          collapse-all     none          0.210379
#                               collapse-layer   none          0.182260
#                               collapse-layer-x none          1.006485
#                               none             none          0.274463
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none           2.693821
#                               collapse-layer   none           2.823657
#                               collapse-layer-x none           2.714206
#                               none             none           2.669222
#                    4          collapse-all     none           2.638983
#                               collapse-layer   none           3.351806
#                               collapse-layer-x none           2.714206
#                               none             none           2.686692
#                    6          collapse-all     none           2.779383
#                               collapse-layer   none           2.935542
#                               collapse-layer-x none           2.714206
#                               none             none           2.712496
#
# domain                                                        spanner  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          1.834313
#                               collapse-layer   none          1.943267
#                               collapse-layer-x none          1.972617
#                               none             none          1.725684
#                    4          collapse-all     none          1.658418
#                               collapse-layer   none          1.700438
#                               collapse-layer-x none          1.972617
#                               none             none          1.671015
#                    6          collapse-all     none          1.661486
#                               collapse-layer   none          1.698590
#                               collapse-layer-x none          1.972617
#                               none             none          1.668549
#
# domain                                                       transport
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none           0.693160
#                               collapse-layer   none           0.723282
#                               collapse-layer-x none           2.080684
#                               none             none           0.708893
#                    4          collapse-all     none           0.083794
#                               collapse-layer   none           0.129761
#                               collapse-layer-x none           2.080684
#                               none             none           0.084280
#                    6          collapse-all     none           0.036001
#                               collapse-layer   none           0.100067
#                               collapse-layer-x none           2.080684
#                               none             none           0.032594
# f1_macro
# domain                                                       blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none             0.622186
#                               collapse-layer   none             0.622305
#                               collapse-layer-x none             0.263711
#                               none             none             0.621567
#                    4          collapse-all     none             1.000000
#                               collapse-layer   none             0.952579
#                               collapse-layer-x none             0.263711
#                               none             none             1.000000
#                    6          collapse-all     none             1.000000
#                               collapse-layer   none             0.940083
#                               collapse-layer-x none             0.263711
#                               none             none             1.000000
#
# domain                                                       childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none            0.209459
#                               collapse-layer   none            0.257630
#                               collapse-layer-x none            0.278336
#                               none             none            0.252132
#                    4          collapse-all     none            0.204988
#                               collapse-layer   none            0.249039
#                               collapse-layer-x none            0.278336
#                               none             none            0.263305
#                    6          collapse-all     none            0.204653
#                               collapse-layer   none            0.245798
#                               collapse-layer-x none            0.278336
#                               none             none            0.332664
#
# domain                                                          ferry  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.904542
#                               collapse-layer   none          0.904542
#                               collapse-layer-x none          0.771552
#                               none             none          0.904542
#                    4          collapse-all     none          0.948551
#                               collapse-layer   none          0.904542
#                               collapse-layer-x none          0.771552
#                               none             none          0.949564
#                    6          collapse-all     none          0.976142
#                               collapse-layer   none          0.904542
#                               collapse-layer-x none          0.771552
#                               none             none          0.976142
#
# domain                                                        miconic  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.366664
#                               collapse-layer   none          0.352895
#                               collapse-layer-x none          0.344281
#                               none             none          0.348837
#                    4          collapse-all     none          0.351767
#                               collapse-layer   none          0.352187
#                               collapse-layer-x none          0.344281
#                               none             none          0.359890
#                    6          collapse-all     none          0.351767
#                               collapse-layer   none          0.357697
#                               collapse-layer-x none          0.344281
#                               none             none          0.383493
#
# domain                                                         rovers  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.783958
#                               collapse-layer   none          0.784829
#                               collapse-layer-x none          0.519659
#                               none             none          0.787643
#                    4          collapse-all     none          0.900707
#                               collapse-layer   none          0.898595
#                               collapse-layer-x none          0.519659
#                               none             none          0.894678
#                    6          collapse-all     none          0.881612
#                               collapse-layer   none          0.896586
#                               collapse-layer-x none          0.519659
#                               none             none          0.891806
#
# domain                                                       satellite  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none           0.000000
#                               collapse-layer   none           0.000000
#                               collapse-layer-x none           0.002064
#                               none             none           0.000000
#                    4          collapse-all     none           0.000000
#                               collapse-layer   none           0.000283
#                               collapse-layer-x none           0.002064
#                               none             none           0.000285
#                    6          collapse-all     none           0.000000
#                               collapse-layer   none           0.000282
#                               collapse-layer-x none           0.002064
#                               none             none           0.000000
#
# domain                                                        spanner  \
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none          0.179302
#                               collapse-layer   none          0.161520
#                               collapse-layer-x none          0.208184
#                               none             none          0.261382
#                    4          collapse-all     none          0.301570
#                               collapse-layer   none          0.288699
#                               collapse-layer-x none          0.208184
#                               none             none          0.299427
#                    6          collapse-all     none          0.301570
#                               collapse-layer   none          0.288743
#                               collapse-layer-x none          0.208184
#                               none             none          0.300668
#
# domain                                                       transport
# optimiser features iterations feature_pruning  data_pruning
# svr       wl       2          collapse-all     none           0.507539
#                               collapse-layer   none           0.500789
#                               collapse-layer-x none           0.214170
#                               none             none           0.504410
#                    4          collapse-all     none           0.924085
#                               collapse-layer   none           0.906617
#                               collapse-layer-x none           0.214170
#                               none             none           0.921788
#                    6          collapse-all     none           0.981395
#                               collapse-layer   none           0.934695
#                               collapse-layer-x none           0.214170
#                               none             none           0.980633
