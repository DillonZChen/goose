# %%
from data.helper import *

# %%
DF = get_train_df()
# Out:
# 100%|██████████| 320/320 [00:00<00:00, 12941.01it/s]

# %%
COLUMNS = [
    "data_pruning",
    "facts",
    "optimiser",
    "features",
    "iterations",
    "feature_pruning",
]

# %%
for metric in [
    # "n_data",
    "n_colours",
    "mse_loss",
    "f1_macro",
]:
    print(metric)
    df = DF.copy()
    # df = df[df.facts == "all"]
    # df = df[df.features == "wl"]
    # df = df[df.data_pruning == "none"]
    # df = df[df.completed]
    Models = {"svr"}
    if metric in {"n_colours", "n_data"}:
        Models.add("rank-svm")
    df = df[df["optimiser"].isin(Models)]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(COLUMNS + ["domain"]).max().reset_index()
    df = df[COLUMNS + ["domain", metric]]
    # pivot table
    df = df.pivot_table(index=COLUMNS, values=metric, columns="domain")
    # make entries int2
    if metric in {"n_colours", "n_data"}:
        df = df.fillna(0)
        df = df.astype(int)
    # display(df)
    # display df without hiding rows
    with pd.option_context("display.max_rows", None):
        display(df)
# Out:
# n_colours
# domain                                                                    blocksworld  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all              316
#                                                         collapse-layer            320
#                                                         collapse-layer-x           41
#                                                         none                      358
#                                              4          collapse-all            10506
#                                                         collapse-layer           3577
#                                                         collapse-layer-x           41
#                                                         none                    22836
#                           svr       wl       2          collapse-all              306
#                                                         collapse-layer            310
#                                                         collapse-layer-x           41
#                                                         none                      348
#                                              4          collapse-all             3218
#                                                         collapse-layer           1771
#                                                         collapse-layer-x           41
#                                                         none                    10445
# none                fd    rank-svm  wl       2          collapse-all              316
#                                                         collapse-layer            320
#                                                         collapse-layer-x           41
#                                                         none                      358
#                                              4          collapse-all            10506
#                                                         collapse-layer           3577
#                                                         collapse-layer-x           41
#                                                         none                    22836
#                           svr       wl       2          collapse-all              306
#                                                         collapse-layer            310
#                                                         collapse-layer-x           41
#                                                         none                      348
#                                              4          collapse-all             3218
#                                                         collapse-layer           1771
#                                                         collapse-layer-x           41
#                                                         none                    10445
#
# domain                                                                    childsnack  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all              51
#                                                         collapse-layer            61
#                                                         collapse-layer-x          24
#                                                         none                      86
#                                              4          collapse-all             122
#                                                         collapse-layer            96
#                                                         collapse-layer-x          24
#                                                         none                     263
#                           svr       wl       2          collapse-all              51
#                                                         collapse-layer            61
#                                                         collapse-layer-x          24
#                                                         none                      86
#                                              4          collapse-all             104
#                                                         collapse-layer            86
#                                                         collapse-layer-x          24
#                                                         none                     255
# none                fd    rank-svm  wl       2          collapse-all              51
#                                                         collapse-layer            61
#                                                         collapse-layer-x          24
#                                                         none                      86
#                                              4          collapse-all             122
#                                                         collapse-layer            96
#                                                         collapse-layer-x          24
#                                                         none                     263
#                           svr       wl       2          collapse-all              51
#                                                         collapse-layer            61
#                                                         collapse-layer-x          24
#                                                         none                      86
#                                              4          collapse-all             104
#                                                         collapse-layer            86
#                                                         collapse-layer-x          24
#                                                         none                     255
#
# domain                                                                    ferry  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all        267
#                                                         collapse-layer      207
#                                                         collapse-layer-x     79
#                                                         none                373
#                                              4          collapse-all       2373
#                                                         collapse-layer      217
#                                                         collapse-layer-x     79
#                                                         none               4398
#                           svr       wl       2          collapse-all        247
#                                                         collapse-layer      193
#                                                         collapse-layer-x     73
#                                                         none                346
#                                              4          collapse-all       1507
#                                                         collapse-layer      203
#                                                         collapse-layer-x     73
#                                                         none               3232
# none                fd    rank-svm  wl       2          collapse-all        267
#                                                         collapse-layer      207
#                                                         collapse-layer-x     79
#                                                         none                373
#                                              4          collapse-all       2373
#                                                         collapse-layer      217
#                                                         collapse-layer-x     79
#                                                         none               4398
#                           svr       wl       2          collapse-all        247
#                                                         collapse-layer      193
#                                                         collapse-layer-x     73
#                                                         none                346
#                                              4          collapse-all       1507
#                                                         collapse-layer      203
#                                                         collapse-layer-x     73
#                                                         none               3232
#
# domain                                                                    floortile  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all           2290
#                                                         collapse-layer         1543
#                                                         collapse-layer-x        428
#                                                         none                   2647
#                                              4          collapse-all          13380
#                                                         collapse-layer         2262
#                                                         collapse-layer-x        428
#                                                         none                  19828
#                           svr       wl       2          collapse-all           1144
#                                                         collapse-layer          706
#                                                         collapse-layer-x        258
#                                                         none                   1318
#                                              4          collapse-all           5444
#                                                         collapse-layer          757
#                                                         collapse-layer-x        258
#                                                         none                   7620
# none                fd    rank-svm  wl       2          collapse-all           2290
#                                                         collapse-layer         1543
#                                                         collapse-layer-x        428
#                                                         none                   2647
#                                              4          collapse-all          13380
#                                                         collapse-layer         2262
#                                                         collapse-layer-x        428
#                                                         none                     -1
#                           svr       wl       2          collapse-all           1144
#                                                         collapse-layer          706
#                                                         collapse-layer-x        258
#                                                         none                   1318
#                                              4          collapse-all           5444
#                                                         collapse-layer          757
#                                                         collapse-layer-x        258
#                                                         none                   7620
#
# domain                                                                    miconic  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all           27
#                                                         collapse-layer         26
#                                                         collapse-layer-x       14
#                                                         none                   47
#                                              4          collapse-all           20
#                                                         collapse-layer         28
#                                                         collapse-layer-x       14
#                                                         none                  112
#                           svr       wl       2          collapse-all           27
#                                                         collapse-layer         26
#                                                         collapse-layer-x       14
#                                                         none                   47
#                                              4          collapse-all           20
#                                                         collapse-layer         28
#                                                         collapse-layer-x       14
#                                                         none                  112
# none                fd    rank-svm  wl       2          collapse-all           27
#                                                         collapse-layer         26
#                                                         collapse-layer-x       14
#                                                         none                   47
#                                              4          collapse-all           20
#                                                         collapse-layer         28
#                                                         collapse-layer-x       14
#                                                         none                  112
#                           svr       wl       2          collapse-all           27
#                                                         collapse-layer         26
#                                                         collapse-layer-x       14
#                                                         none                   47
#                                              4          collapse-all           20
#                                                         collapse-layer         28
#                                                         collapse-layer-x       14
#                                                         none                  112
#
# domain                                                                    rovers  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all        5036
#                                                         collapse-layer      4984
#                                                         collapse-layer-x     363
#                                                         none                6729
#                                              4          collapse-all          -1
#                                                         collapse-layer     13947
#                                                         collapse-layer-x     363
#                                                         none                  -1
#                           svr       wl       2          collapse-all        2156
#                                                         collapse-layer      2158
#                                                         collapse-layer-x     279
#                                                         none                3404
#                                              4          collapse-all        4529
#                                                         collapse-layer      4583
#                                                         collapse-layer-x     279
#                                                         none               23206
# none                fd    rank-svm  wl       2          collapse-all        5036
#                                                         collapse-layer      4984
#                                                         collapse-layer-x     363
#                                                         none                6729
#                                              4          collapse-all          -1
#                                                         collapse-layer     13947
#                                                         collapse-layer-x     363
#                                                         none                  -1
#                           svr       wl       2          collapse-all        2156
#                                                         collapse-layer      2158
#                                                         collapse-layer-x     279
#                                                         none                3404
#                                              4          collapse-all        4529
#                                                         collapse-layer      4583
#                                                         collapse-layer-x     279
#                                                         none               23206
#
# domain                                                                    satellite  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all           3882
#                                                         collapse-layer         3896
#                                                         collapse-layer-x        292
#                                                         none                   4265
#                                              4          collapse-all             -1
#                                                         collapse-layer           -1
#                                                         collapse-layer-x        292
#                                                         none                     -1
#                           svr       wl       2          collapse-all           1741
#                                                         collapse-layer         1773
#                                                         collapse-layer-x        213
#                                                         none                   2231
#                                              4          collapse-all           5232
#                                                         collapse-layer         5938
#                                                         collapse-layer-x        213
#                                                         none                  22159
# none                fd    rank-svm  wl       2          collapse-all           3882
#                                                         collapse-layer         3896
#                                                         collapse-layer-x        292
#                                                         none                   4265
#                                              4          collapse-all             -1
#                                                         collapse-layer           -1
#                                                         collapse-layer-x        292
#                                                         none                     -1
#                           svr       wl       2          collapse-all           1741
#                                                         collapse-layer         1773
#                                                         collapse-layer-x        213
#                                                         none                   2231
#                                              4          collapse-all           5232
#                                                         collapse-layer         5938
#                                                         collapse-layer-x        213
#                                                         none                  22159
#
# domain                                                                    sokoban  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all           15
#                                                         collapse-layer         28
#                                                         collapse-layer-x       15
#                                                         none                   51
#                                              4          collapse-all           27
#                                                         collapse-layer         30
#                                                         collapse-layer-x       15
#                                                         none                  118
#                           svr       wl       2          collapse-all           15
#                                                         collapse-layer         28
#                                                         collapse-layer-x       15
#                                                         none                   51
#                                              4          collapse-all           22
#                                                         collapse-layer         30
#                                                         collapse-layer-x       15
#                                                         none                  114
# none                fd    rank-svm  wl       2          collapse-all           15
#                                                         collapse-layer         28
#                                                         collapse-layer-x       15
#                                                         none                   51
#                                              4          collapse-all           27
#                                                         collapse-layer         30
#                                                         collapse-layer-x       15
#                                                         none                  118
#                           svr       wl       2          collapse-all           15
#                                                         collapse-layer         28
#                                                         collapse-layer-x       15
#                                                         none                   51
#                                              4          collapse-all           22
#                                                         collapse-layer         30
#                                                         collapse-layer-x       15
#                                                         none                  114
#
# domain                                                                    spanner  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all           69
#                                                         collapse-layer         67
#                                                         collapse-layer-x       21
#                                                         none                   86
#                                              4          collapse-all          207
#                                                         collapse-layer        106
#                                                         collapse-layer-x       21
#                                                         none                  378
#                           svr       wl       2          collapse-all           67
#                                                         collapse-layer         66
#                                                         collapse-layer-x       21
#                                                         none                   85
#                                              4          collapse-all          188
#                                                         collapse-layer        103
#                                                         collapse-layer-x       21
#                                                         none                  354
# none                fd    rank-svm  wl       2          collapse-all           69
#                                                         collapse-layer         67
#                                                         collapse-layer-x       21
#                                                         none                   86
#                                              4          collapse-all          207
#                                                         collapse-layer        106
#                                                         collapse-layer-x       21
#                                                         none                  378
#                           svr       wl       2          collapse-all           67
#                                                         collapse-layer         66
#                                                         collapse-layer-x       21
#                                                         none                   85
#                                              4          collapse-all          188
#                                                         collapse-layer        103
#                                                         collapse-layer-x       21
#                                                         none                  354
#
# domain                                                                    transport
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    rank-svm  wl       2          collapse-all            434
#                                                         collapse-layer          375
#                                                         collapse-layer-x         78
#                                                         none                    465
#                                              4          collapse-all           6545
#                                                         collapse-layer         3129
#                                                         collapse-layer-x         78
#                                                         none                   8936
#                           svr       wl       2          collapse-all            292
#                                                         collapse-layer          257
#                                                         collapse-layer-x         60
#                                                         none                    331
#                                              4          collapse-all           2255
#                                                         collapse-layer         1295
#                                                         collapse-layer-x         60
#                                                         none                   3791
# none                fd    rank-svm  wl       2          collapse-all            434
#                                                         collapse-layer          375
#                                                         collapse-layer-x         78
#                                                         none                    465
#                                              4          collapse-all           6545
#                                                         collapse-layer         3129
#                                                         collapse-layer-x         78
#                                                         none                   8936
#                           svr       wl       2          collapse-all            292
#                                                         collapse-layer          257
#                                                         collapse-layer-x         60
#                                                         none                    331
#                                              4          collapse-all           2255
#                                                         collapse-layer         1295
#                                                         collapse-layer-x         60
#                                                         none                   3791
# mse_loss
# domain                                                                    blocksworld  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all         0.510350
#                                                         collapse-layer       0.513817
#                                                         collapse-layer-x     3.961967
#                                                         none                 0.500857
#                                              4          collapse-all         0.000425
#                                                         collapse-layer       0.091669
#                                                         collapse-layer-x     3.961967
#                                                         none                 0.004913
# none                fd    svr       wl       2          collapse-all         0.511368
#                                                         collapse-layer       0.509068
#                                                         collapse-layer-x     3.987980
#                                                         none                 0.507346
#                                              4          collapse-all         0.000421
#                                                         collapse-layer       0.091440
#                                                         collapse-layer-x     3.987980
#                                                         none                 0.004935
#
# domain                                                                    childsnack  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all        0.519599
#                                                         collapse-layer      0.622322
#                                                         collapse-layer-x    0.749930
#                                                         none                0.486102
#                                              4          collapse-all        0.803501
#                                                         collapse-layer      0.461384
#                                                         collapse-layer-x    0.749930
#                                                         none                0.520843
# none                fd    svr       wl       2          collapse-all        1.139566
#                                                         collapse-layer      0.815809
#                                                         collapse-layer-x    0.704940
#                                                         none                0.711446
#                                              4          collapse-all        1.289815
#                                                         collapse-layer      0.862840
#                                                         collapse-layer-x    0.704940
#                                                         none                0.574822
#
# domain                                                                       ferry  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.085750
#                                                         collapse-layer    0.100328
#                                                         collapse-layer-x  0.197522
#                                                         none              0.081878
#                                              4          collapse-all      0.050855
#                                                         collapse-layer    0.100700
#                                                         collapse-layer-x  0.197522
#                                                         none              0.046121
# none                fd    svr       wl       2          collapse-all      0.085744
#                                                         collapse-layer    0.100333
#                                                         collapse-layer-x  0.197528
#                                                         none              0.081969
#                                              4          collapse-all      0.049911
#                                                         collapse-layer    0.100699
#                                                         collapse-layer-x  0.197528
#                                                         none              0.044637
#
# domain                                                                    floortile  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       0.787910
#                                                         collapse-layer     0.772657
#                                                         collapse-layer-x   0.775366
#                                                         none               1.165632
#                                              4          collapse-all       0.623404
#                                                         collapse-layer     0.782150
#                                                         collapse-layer-x   0.775366
#                                                         none               0.599032
# none                fd    svr       wl       2          collapse-all       0.863586
#                                                         collapse-layer     0.806845
#                                                         collapse-layer-x   0.790067
#                                                         none               0.815996
#                                              4          collapse-all       0.646432
#                                                         collapse-layer     0.803673
#                                                         collapse-layer-x   0.790067
#                                                         none               0.644310
#
# domain                                                                     miconic  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.764027
#                                                         collapse-layer    0.768322
#                                                         collapse-layer-x  0.790884
#                                                         none              0.760220
#                                              4          collapse-all      0.766491
#                                                         collapse-layer    0.778514
#                                                         collapse-layer-x  0.790884
#                                                         none              0.765921
# none                fd    svr       wl       2          collapse-all      0.760557
#                                                         collapse-layer    0.766507
#                                                         collapse-layer-x  0.784374
#                                                         none              0.763411
#                                              4          collapse-all      0.763184
#                                                         collapse-layer    0.769398
#                                                         collapse-layer-x  0.784374
#                                                         none              0.761053
#
# domain                                                                      rovers  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.428965
#                                                         collapse-layer    0.434578
#                                                         collapse-layer-x  0.995685
#                                                         none              0.448051
#                                              4          collapse-all      0.202250
#                                                         collapse-layer    0.185959
#                                                         collapse-layer-x  0.995685
#                                                         none              0.207600
# none                fd    svr       wl       2          collapse-all      0.430194
#                                                         collapse-layer    0.433503
#                                                         collapse-layer-x  1.006485
#                                                         none              0.447003
#                                              4          collapse-all      0.201610
#                                                         collapse-layer    0.186038
#                                                         collapse-layer-x  1.006485
#                                                         none              0.230729
#
# domain                                                                    satellite  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       2.693499
#                                                         collapse-layer     2.685213
#                                                         collapse-layer-x   2.950527
#                                                         none               2.623987
#                                              4          collapse-all       2.669571
#                                                         collapse-layer     3.314768
#                                                         collapse-layer-x   2.950527
#                                                         none               2.684553
# none                fd    svr       wl       2          collapse-all       2.803872
#                                                         collapse-layer     2.823657
#                                                         collapse-layer-x   2.714206
#                                                         none               2.669222
#                                              4          collapse-all       2.678003
#                                                         collapse-layer     3.351806
#                                                         collapse-layer-x   2.714206
#                                                         none               2.686692
#
# domain                                                                      sokoban  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      69.921202
#                                                         collapse-layer    51.283163
#                                                         collapse-layer-x  69.921202
#                                                         none              86.566183
#                                              4          collapse-all      54.591906
#                                                         collapse-layer    50.877990
#                                                         collapse-layer-x  69.921202
#                                                         none              50.210058
# none                fd    svr       wl       2          collapse-all      66.228274
#                                                         collapse-layer    65.252920
#                                                         collapse-layer-x  66.228274
#                                                         none              53.199132
#                                              4          collapse-all      67.467223
#                                                         collapse-layer    52.498732
#                                                         collapse-layer-x  66.228274
#                                                         none              57.124089
#
# domain                                                                     spanner  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      1.767831
#                                                         collapse-layer    1.884141
#                                                         collapse-layer-x  1.899760
#                                                         none              1.782436
#                                              4          collapse-all      1.658950
#                                                         collapse-layer    1.683115
#                                                         collapse-layer-x  1.899760
#                                                         none              1.634928
# none                fd    svr       wl       2          collapse-all      1.849630
#                                                         collapse-layer    1.943267
#                                                         collapse-layer-x  1.972617
#                                                         none              1.725684
#                                              4          collapse-all      1.659894
#                                                         collapse-layer    1.700438
#                                                         collapse-layer-x  1.972617
#                                                         none              1.671015
#
# domain                                                                    transport
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       0.737886
#                                                         collapse-layer     0.701056
#                                                         collapse-layer-x   2.051823
#                                                         none               0.718594
#                                              4          collapse-all       0.084535
#                                                         collapse-layer     0.132093
#                                                         collapse-layer-x   2.051823
#                                                         none               0.084015
# none                fd    svr       wl       2          collapse-all       0.712949
#                                                         collapse-layer     0.723282
#                                                         collapse-layer-x   2.080684
#                                                         none               0.708893
#                                              4          collapse-all       0.084458
#                                                         collapse-layer     0.129761
#                                                         collapse-layer-x   2.080684
#                                                         none               0.084280
# f1_macro
# domain                                                                    blocksworld  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all         0.621674
#                                                         collapse-layer       0.622793
#                                                         collapse-layer-x     0.280503
#                                                         none                 0.621186
#                                              4          collapse-all         1.000000
#                                                         collapse-layer       0.953034
#                                                         collapse-layer-x     0.280503
#                                                         none                 1.000000
# none                fd    svr       wl       2          collapse-all         0.621708
#                                                         collapse-layer       0.622305
#                                                         collapse-layer-x     0.263711
#                                                         none                 0.621567
#                                              4          collapse-all         1.000000
#                                                         collapse-layer       0.952579
#                                                         collapse-layer-x     0.263711
#                                                         none                 1.000000
#
# domain                                                                    childsnack  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all        0.423041
#                                                         collapse-layer      0.299360
#                                                         collapse-layer-x    0.264180
#                                                         none                0.469199
#                                              4          collapse-all        0.242808
#                                                         collapse-layer      0.475540
#                                                         collapse-layer-x    0.264180
#                                                         none                0.365337
# none                fd    svr       wl       2          collapse-all        0.209459
#                                                         collapse-layer      0.257630
#                                                         collapse-layer-x    0.278336
#                                                         none                0.252132
#                                              4          collapse-all        0.204988
#                                                         collapse-layer      0.249039
#                                                         collapse-layer-x    0.278336
#                                                         none                0.263305
#
# domain                                                                       ferry  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.904542
#                                                         collapse-layer    0.904542
#                                                         collapse-layer-x  0.771552
#                                                         none              0.904542
#                                              4          collapse-all      0.948234
#                                                         collapse-layer    0.904542
#                                                         collapse-layer-x  0.771552
#                                                         none              0.948551
# none                fd    svr       wl       2          collapse-all      0.904542
#                                                         collapse-layer    0.904542
#                                                         collapse-layer-x  0.771552
#                                                         none              0.904542
#                                              4          collapse-all      0.948551
#                                                         collapse-layer    0.904542
#                                                         collapse-layer-x  0.771552
#                                                         none              0.949564
#
# domain                                                                    floortile  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       0.460061
#                                                         collapse-layer     0.477970
#                                                         collapse-layer-x   0.336146
#                                                         none               0.272221
#                                              4          collapse-all       0.626398
#                                                         collapse-layer     0.486191
#                                                         collapse-layer-x   0.336146
#                                                         none               0.620250
# none                fd    svr       wl       2          collapse-all       0.477823
#                                                         collapse-layer     0.476810
#                                                         collapse-layer-x   0.331829
#                                                         none               0.486617
#                                              4          collapse-all       0.647532
#                                                         collapse-layer     0.479013
#                                                         collapse-layer-x   0.331829
#                                                         none               0.648506
#
# domain                                                                     miconic  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.363434
#                                                         collapse-layer    0.366810
#                                                         collapse-layer-x  0.347770
#                                                         none              0.362506
#                                              4          collapse-all      0.366225
#                                                         collapse-layer    0.349875
#                                                         collapse-layer-x  0.347770
#                                                         none              0.353102
# none                fd    svr       wl       2          collapse-all      0.360910
#                                                         collapse-layer    0.352895
#                                                         collapse-layer-x  0.344281
#                                                         none              0.348837
#                                              4          collapse-all      0.351767
#                                                         collapse-layer    0.352187
#                                                         collapse-layer-x  0.344281
#                                                         none              0.359890
#
# domain                                                                      rovers  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.781422
#                                                         collapse-layer    0.786746
#                                                         collapse-layer-x  0.521970
#                                                         none              0.786422
#                                              4          collapse-all      0.902183
#                                                         collapse-layer    0.898045
#                                                         collapse-layer-x  0.521970
#                                                         none              0.896343
# none                fd    svr       wl       2          collapse-all      0.783352
#                                                         collapse-layer    0.784829
#                                                         collapse-layer-x  0.519659
#                                                         none              0.787643
#                                              4          collapse-all      0.902183
#                                                         collapse-layer    0.898595
#                                                         collapse-layer-x  0.519659
#                                                         none              0.894678
#
# domain                                                                    satellite  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       0.000000
#                                                         collapse-layer     0.000000
#                                                         collapse-layer-x   0.001526
#                                                         none               0.000000
#                                              4          collapse-all       0.000283
#                                                         collapse-layer     0.000283
#                                                         collapse-layer-x   0.001526
#                                                         none               0.000285
# none                fd    svr       wl       2          collapse-all       0.000000
#                                                         collapse-layer     0.000000
#                                                         collapse-layer-x   0.002064
#                                                         none               0.000000
#                                              4          collapse-all       0.000283
#                                                         collapse-layer     0.000283
#                                                         collapse-layer-x   0.002064
#                                                         none               0.000285
#
# domain                                                                     sokoban  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.013645
#                                                         collapse-layer    0.021861
#                                                         collapse-layer-x  0.013645
#                                                         none              0.017534
#                                              4          collapse-all      0.018976
#                                                         collapse-layer    0.023015
#                                                         collapse-layer-x  0.013645
#                                                         none              0.020343
# none                fd    svr       wl       2          collapse-all      0.012487
#                                                         collapse-layer    0.016080
#                                                         collapse-layer-x  0.012487
#                                                         none              0.019411
#                                              4          collapse-all      0.013068
#                                                         collapse-layer    0.021333
#                                                         collapse-layer-x  0.012487
#                                                         none              0.014972
#
# domain                                                                     spanner  \
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all      0.234541
#                                                         collapse-layer    0.181334
#                                                         collapse-layer-x  0.233076
#                                                         none              0.210778
#                                              4          collapse-all      0.300598
#                                                         collapse-layer    0.292682
#                                                         collapse-layer-x  0.233076
#                                                         none              0.301867
# none                fd    svr       wl       2          collapse-all      0.170806
#                                                         collapse-layer    0.161520
#                                                         collapse-layer-x  0.208184
#                                                         none              0.261382
#                                              4          collapse-all      0.301570
#                                                         collapse-layer    0.288699
#                                                         collapse-layer-x  0.208184
#                                                         none              0.299427
#
# domain                                                                    transport
# data_pruning        facts optimiser features iterations feature_pruning
# equivalent-weighted fd    svr       wl       2          collapse-all       0.482648
#                                                         collapse-layer     0.502696
#                                                         collapse-layer-x   0.217809
#                                                         none               0.493159
#                                              4          collapse-all       0.924269
#                                                         collapse-layer     0.909336
#                                                         collapse-layer-x   0.217809
#                                                         none               0.922979
# none                fd    svr       wl       2          collapse-all       0.500706
#                                                         collapse-layer     0.500789
#                                                         collapse-layer-x   0.214170
#                                                         none               0.504410
#                                              4          collapse-all       0.923425
#                                                         collapse-layer     0.906617
#                                                         collapse-layer-x   0.214170
#                                                         none               0.921788
