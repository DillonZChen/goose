# %%
from data.helper import *

# %%
DF = get_train_df()
# Out:
# 100%|██████████| 2304/2304 [00:00<00:00, 5454.44it/s]

# %%
COLUMNS = [
    "optimiser",
    "features",
    "iterations",
    "feature_pruning",
    "data_pruning",
]

# %%
for metric in [
    # "n_data",
    "n_colours",
    "mse_loss",
    "f1_macro",
]:
    print(metric)
    df = DF.copy()
    df = df[df.facts == "all"]
    # df = df[df.features == "wl"]
    # df = df[df.data_pruning == "none"]
    # df = df[df.completed]
    Models = {"svr"}
    if metric in {"n_colours", "n_data"}:
        Models.add("rank-svm")
    df = df[df["optimiser"].isin(Models)]
    # combine rows with same pruning, optimiser and iterations
    df = df.groupby(COLUMNS + ["domain"]).max().reset_index()
    df = df[COLUMNS + ["domain", metric]]
    # pivot table
    df = df.pivot_table(index=COLUMNS, values=metric, columns="domain")
    # make entries int2
    if metric in {"n_colours", "n_data"}:
        df = df.fillna(0)
        df = df.astype(int)
    # display(df)
    # display df without hiding rows
    with pd.option_context("display.max_rows", None):
        display(df)
# Out:
# n_colours
# domain                                                              blocksworld  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  lwl2     2          collapse-all     equivalent                 32046
#                                                equivalent-weighted           -1
#                                                none                       32046
#                               collapse-layer   equivalent                 24736
#                                                equivalent-weighted           -1
#                                                none                       24736
#                               collapse-layer-x equivalent                 22975
#                                                equivalent-weighted           -1
#                                                none                       22975
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                    4          collapse-all     equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                               collapse-layer   equivalent                 31557
#                                                equivalent-weighted           -1
#                                                none                       31557
#                               collapse-layer-x equivalent                 27973
#                                                equivalent-weighted           -1
#                                                none                       27973
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                    6          collapse-all     equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                               collapse-layer   equivalent                 31613
#                                                equivalent-weighted           -1
#                                                none                       31613
#                               collapse-layer-x equivalent                 28009
#                                                equivalent-weighted           -1
#                                                none                       28009
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#           wl       2          collapse-all     equivalent                   349
#                                                equivalent-weighted           -1
#                                                none                         349
#                               collapse-layer   equivalent                   320
#                                                equivalent-weighted           -1
#                                                none                         320
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                   358
#                                                equivalent-weighted           -1
#                                                none                         358
#                    4          collapse-all     equivalent                 13273
#                                                equivalent-weighted           -1
#                                                none                       13273
#                               collapse-layer   equivalent                  3577
#                                                equivalent-weighted           -1
#                                                none                        3577
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                 22836
#                                                equivalent-weighted           -1
#                                                none                       22836
#                    6          collapse-all     equivalent                 24619
#                                                equivalent-weighted           -1
#                                                none                       24619
#                               collapse-layer   equivalent                  4390
#                                                equivalent-weighted           -1
#                                                none                        4390
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
# svr       lwl2     2          collapse-all     equivalent                 17033
#                                                equivalent-weighted           -1
#                                                none                       17033
#                               collapse-layer   equivalent                 11858
#                                                equivalent-weighted           -1
#                                                none                       11858
#                               collapse-layer-x equivalent                 10712
#                                                equivalent-weighted           -1
#                                                none                       10712
#                               none             equivalent                 49140
#                                                equivalent-weighted           -1
#                                                none                       49140
#                    4          collapse-all     equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                               collapse-layer   equivalent                 13948
#                                                equivalent-weighted           -1
#                                                none                       13948
#                               collapse-layer-x equivalent                 11579
#                                                equivalent-weighted           -1
#                                                none                       11579
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                    6          collapse-all     equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#                               collapse-layer   equivalent                 13996
#                                                equivalent-weighted           -1
#                                                none                       13996
#                               collapse-layer-x equivalent                 11596
#                                                equivalent-weighted           -1
#                                                none                       11596
#                               none             equivalent                    -1
#                                                equivalent-weighted           -1
#                                                none                          -1
#           wl       2          collapse-all     equivalent                   339
#                                                equivalent-weighted           -1
#                                                none                         339
#                               collapse-layer   equivalent                   310
#                                                equivalent-weighted           -1
#                                                none                         310
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                   348
#                                                equivalent-weighted           -1
#                                                none                         348
#                    4          collapse-all     equivalent                  4514
#                                                equivalent-weighted           -1
#                                                none                        4514
#                               collapse-layer   equivalent                  1771
#                                                equivalent-weighted           -1
#                                                none                        1771
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                 10445
#                                                equivalent-weighted           -1
#                                                none                       10445
#                    6          collapse-all     equivalent                  5181
#                                                equivalent-weighted           -1
#                                                none                        5181
#                               collapse-layer   equivalent                  1941
#                                                equivalent-weighted           -1
#                                                none                        1941
#                               collapse-layer-x equivalent                    41
#                                                equivalent-weighted           -1
#                                                none                          41
#                               none             equivalent                 41816
#                                                equivalent-weighted           -1
#                                                none                       41816
#
# domain                                                              childsnack  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  lwl2     2          collapse-all     equivalent                 3726
#                                                equivalent-weighted          -1
#                                                none                       3726
#                               collapse-layer   equivalent                 1814
#                                                equivalent-weighted          -1
#                                                none                       1814
#                               collapse-layer-x equivalent                 1218
#                                                equivalent-weighted          -1
#                                                none                       1218
#                               none             equivalent                 7821
#                                                equivalent-weighted          -1
#                                                none                       7821
#                    4          collapse-all     equivalent                25389
#                                                equivalent-weighted          -1
#                                                none                      25389
#                               collapse-layer   equivalent                 1861
#                                                equivalent-weighted          -1
#                                                none                       1861
#                               collapse-layer-x equivalent                 1222
#                                                equivalent-weighted          -1
#                                                none                       1222
#                               none             equivalent                66899
#                                                equivalent-weighted          -1
#                                                none                         -1
#                    6          collapse-all     equivalent                   -1
#                                                equivalent-weighted          -1
#                                                none                         -1
#                               collapse-layer   equivalent                 1885
#                                                equivalent-weighted          -1
#                                                none                       1885
#                               collapse-layer-x equivalent                 1222
#                                                equivalent-weighted          -1
#                                                none                       1222
#                               none             equivalent                   -1
#                                                equivalent-weighted          -1
#                                                none                         -1
#           wl       2          collapse-all     equivalent                  172
#                                                equivalent-weighted          -1
#                                                none                        172
#                               collapse-layer   equivalent                  177
#                                                equivalent-weighted          -1
#                                                none                        177
#                               collapse-layer-x equivalent                   49
#                                                equivalent-weighted          -1
#                                                none                         49
#                               none             equivalent                  208
#                                                equivalent-weighted          -1
#                                                none                        208
#                    4          collapse-all     equivalent                 1141
#                                                equivalent-weighted          -1
#                                                none                       1141
#                               collapse-layer   equivalent                  664
#                                                equivalent-weighted          -1
#                                                none                        664
#                               collapse-layer-x equivalent                   49
#                                                equivalent-weighted          -1
#                                                none                         49
#                               none             equivalent                 1553
#                                                equivalent-weighted          -1
#                                                none                       1553
#                    6          collapse-all     equivalent                 2146
#                                                equivalent-weighted          -1
#                                                none                       2146
#                               collapse-layer   equivalent                  678
#                                                equivalent-weighted          -1
#                                                none                        678
#                               collapse-layer-x equivalent                   49
#                                                equivalent-weighted          -1
#                                                none                         49
#                               none             equivalent                 5074
#                                                equivalent-weighted          -1
#                                                none                       5074
# svr       lwl2     2          collapse-all     equivalent                 2652
#                                                equivalent-weighted          -1
#                                                none                       2652
#                               collapse-layer   equivalent                 1365
#                                                equivalent-weighted          -1
#                                                none                       1365
#                               collapse-layer-x equivalent                  977
#                                                equivalent-weighted          -1
#                                                none                        977
#                               none             equivalent                 6049
#                                                equivalent-weighted          -1
#                                                none                       6049
#                    4          collapse-all     equivalent                15410
#                                                equivalent-weighted          -1
#                                                none                      15410
#                               collapse-layer   equivalent                 1396
#                                                equivalent-weighted          -1
#                                                none                       1396
#                               collapse-layer-x equivalent                  978
#                                                equivalent-weighted          -1
#                                                none                        978
#                               none             equivalent                36008
#                                                equivalent-weighted          -1
#                                                none                      36008
#                    6          collapse-all     equivalent                   -1
#                                                equivalent-weighted          -1
#                                                none                         -1
#                               collapse-layer   equivalent                 1416
#                                                equivalent-weighted          -1
#                                                none                       1416
#                               collapse-layer-x equivalent                  978
#                                                equivalent-weighted          -1
#                                                none                        978
#                               none             equivalent                88008
#                                                equivalent-weighted          -1
#                                                none                      88008
#           wl       2          collapse-all     equivalent                  156
#                                                equivalent-weighted          -1
#                                                none                        156
#                               collapse-layer   equivalent                  155
#                                                equivalent-weighted          -1
#                                                none                        155
#                               collapse-layer-x equivalent                   45
#                                                equivalent-weighted          -1
#                                                none                         45
#                               none             equivalent                  186
#                                                equivalent-weighted          -1
#                                                none                        186
#                    4          collapse-all     equivalent                  675
#                                                equivalent-weighted          -1
#                                                none                        675
#                               collapse-layer   equivalent                  383
#                                                equivalent-weighted          -1
#                                                none                        383
#                               collapse-layer-x equivalent                   45
#                                                equivalent-weighted          -1
#                                                none                         45
#                               none             equivalent                  989
#                                                equivalent-weighted          -1
#                                                none                        989
#                    6          collapse-all     equivalent                  983
#                                                equivalent-weighted          -1
#                                                none                        983
#                               collapse-layer   equivalent                  385
#                                                equivalent-weighted          -1
#                                                none                        385
#                               collapse-layer-x equivalent                   45
#                                                equivalent-weighted          -1
#                                                none                         45
#                               none             equivalent                 2659
#                                                equivalent-weighted          -1
#                                                none                       2659
#
# domain                                                               ferry  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  lwl2     2          collapse-all     equivalent             9322
#                                                equivalent-weighted      -1
#                                                none                   9322
#                               collapse-layer   equivalent             4425
#                                                equivalent-weighted      -1
#                                                none                   4425
#                               collapse-layer-x equivalent             3211
#                                                equivalent-weighted      -1
#                                                none                   3211
#                               none             equivalent            17839
#                                                equivalent-weighted      -1
#                                                none                  17839
#                    4          collapse-all     equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               collapse-layer   equivalent             4681
#                                                equivalent-weighted      -1
#                                                none                   4681
#                               collapse-layer-x equivalent             3223
#                                                equivalent-weighted      -1
#                                                none                   3223
#                               none             equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                    6          collapse-all     equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               collapse-layer   equivalent             4699
#                                                equivalent-weighted      -1
#                                                none                   4699
#                               collapse-layer-x equivalent             3223
#                                                equivalent-weighted      -1
#                                                none                   3223
#                               none             equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#           wl       2          collapse-all     equivalent              334
#                                                equivalent-weighted      -1
#                                                none                    334
#                               collapse-layer   equivalent              207
#                                                equivalent-weighted      -1
#                                                none                    207
#                               collapse-layer-x equivalent               79
#                                                equivalent-weighted      -1
#                                                none                     79
#                               none             equivalent              373
#                                                equivalent-weighted      -1
#                                                none                    373
#                    4          collapse-all     equivalent             3004
#                                                equivalent-weighted      -1
#                                                none                   3004
#                               collapse-layer   equivalent              217
#                                                equivalent-weighted      -1
#                                                none                    217
#                               collapse-layer-x equivalent               79
#                                                equivalent-weighted      -1
#                                                none                     79
#                               none             equivalent             4398
#                                                equivalent-weighted      -1
#                                                none                   4398
#                    6          collapse-all     equivalent            14952
#                                                equivalent-weighted      -1
#                                                none                  14952
#                               collapse-layer   equivalent              221
#                                                equivalent-weighted      -1
#                                                none                    221
#                               collapse-layer-x equivalent               79
#                                                equivalent-weighted      -1
#                                                none                     79
#                               none             equivalent            25515
#                                                equivalent-weighted      -1
#                                                none                  25515
# svr       lwl2     2          collapse-all     equivalent             6734
#                                                equivalent-weighted      -1
#                                                none                   6734
#                               collapse-layer   equivalent             3185
#                                                equivalent-weighted      -1
#                                                none                   3185
#                               collapse-layer-x equivalent             2307
#                                                equivalent-weighted      -1
#                                                none                   2307
#                               none             equivalent            13679
#                                                equivalent-weighted      -1
#                                                none                  13679
#                    4          collapse-all     equivalent            49282
#                                                equivalent-weighted      -1
#                                                none                  49282
#                               collapse-layer   equivalent             3386
#                                                equivalent-weighted      -1
#                                                none                   3386
#                               collapse-layer-x equivalent             2319
#                                                equivalent-weighted      -1
#                                                none                   2319
#                               none             equivalent           181674
#                                                equivalent-weighted      -1
#                                                none                 181674
#                    6          collapse-all     equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               collapse-layer   equivalent             3404
#                                                equivalent-weighted      -1
#                                                none                   3404
#                               collapse-layer-x equivalent             2319
#                                                equivalent-weighted      -1
#                                                none                   2319
#                               none             equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#           wl       2          collapse-all     equivalent              314
#                                                equivalent-weighted      -1
#                                                none                    314
#                               collapse-layer   equivalent              193
#                                                equivalent-weighted      -1
#                                                none                    193
#                               collapse-layer-x equivalent               73
#                                                equivalent-weighted      -1
#                                                none                     73
#                               none             equivalent              346
#                                                equivalent-weighted      -1
#                                                none                    346
#                    4          collapse-all     equivalent             1965
#                                                equivalent-weighted      -1
#                                                none                   1965
#                               collapse-layer   equivalent              203
#                                                equivalent-weighted      -1
#                                                none                    203
#                               collapse-layer-x equivalent               73
#                                                equivalent-weighted      -1
#                                                none                     73
#                               none             equivalent             3232
#                                                equivalent-weighted      -1
#                                                none                   3232
#                    6          collapse-all     equivalent             6690
#                                                equivalent-weighted      -1
#                                                none                   6690
#                               collapse-layer   equivalent              207
#                                                equivalent-weighted      -1
#                                                none                    207
#                               collapse-layer-x equivalent               73
#                                                equivalent-weighted      -1
#                                                none                     73
#                               none             equivalent            13586
#                                                equivalent-weighted      -1
#                                                none                  13586
#
# domain                                                              miconic  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  lwl2     2          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                    4          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                    6          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#           wl       2          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent              1622
#                                                equivalent-weighted       -1
#                                                none                    1622
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                    4          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent              1622
#                                                equivalent-weighted       -1
#                                                none                    1622
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                    6          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer-x equivalent              1622
#                                                equivalent-weighted       -1
#                                                none                    1622
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
# svr       lwl2     2          collapse-all     equivalent             51657
#                                                equivalent-weighted       -1
#                                                none                   51657
#                               collapse-layer   equivalent             19481
#                                                equivalent-weighted       -1
#                                                none                   19481
#                               collapse-layer-x equivalent             16794
#                                                equivalent-weighted       -1
#                                                none                   16794
#                               none             equivalent            115825
#                                                equivalent-weighted       -1
#                                                none                  115825
#                    4          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent             21112
#                                                equivalent-weighted       -1
#                                                none                   21112
#                               collapse-layer-x equivalent             18090
#                                                equivalent-weighted       -1
#                                                none                   18090
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                    6          collapse-all     equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#                               collapse-layer   equivalent             21112
#                                                equivalent-weighted       -1
#                                                none                   21112
#                               collapse-layer-x equivalent             18090
#                                                equivalent-weighted       -1
#                                                none                   18090
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#           wl       2          collapse-all     equivalent             16314
#                                                equivalent-weighted       -1
#                                                none                   16314
#                               collapse-layer   equivalent              9001
#                                                equivalent-weighted       -1
#                                                none                    9001
#                               collapse-layer-x equivalent              1528
#                                                equivalent-weighted       -1
#                                                none                    1528
#                               none             equivalent             28566
#                                                equivalent-weighted       -1
#                                                none                   28566
#                    4          collapse-all     equivalent             71604
#                                                equivalent-weighted       -1
#                                                none                   71604
#                               collapse-layer   equivalent             11956
#                                                equivalent-weighted       -1
#                                                none                   11956
#                               collapse-layer-x equivalent              1528
#                                                equivalent-weighted       -1
#                                                none                    1528
#                               none             equivalent            237688
#                                                equivalent-weighted       -1
#                                                none                  237688
#                    6          collapse-all     equivalent             78225
#                                                equivalent-weighted       -1
#                                                none                   78225
#                               collapse-layer   equivalent             11956
#                                                equivalent-weighted       -1
#                                                none                   11956
#                               collapse-layer-x equivalent              1528
#                                                equivalent-weighted       -1
#                                                none                    1528
#                               none             equivalent                -1
#                                                equivalent-weighted       -1
#                                                none                      -1
#
# domain                                                              rovers  \
# optimiser features iterations feature_pruning  data_pruning
# rank-svm  lwl2     2          collapse-all     equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               collapse-layer   equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               collapse-layer-x equivalent               -1
#                                                equivalent-weighted      -1
#                                                none                     -1
#                               none             equivalent               -1
# ...
#                               none             equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                    6          collapse-all     equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                               collapse-layer   equivalent            0.992915
#                                                equivalent-weighted  -1.000000
#                                                none                  0.310852
#                               collapse-layer-x equivalent            0.977865
#                                                equivalent-weighted  -1.000000
#                                                none                  0.300418
#                               none             equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#           wl       2          collapse-all     equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer   equivalent            0.999277
#                                                equivalent-weighted  -1.000000
#                                                none                  0.999277
#                               collapse-layer-x equivalent            0.032150
#                                                equivalent-weighted  -1.000000
#                                                none                  0.017381
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                    4          collapse-all     equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            0.032150
#                                                equivalent-weighted  -1.000000
#                                                none                  0.017381
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                    6          collapse-all     equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            0.032150
#                                                equivalent-weighted  -1.000000
#                                                none                  0.017381
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#
# domain                                                               spanner  \
# optimiser features iterations feature_pruning  data_pruning
# svr       lwl2     2          collapse-all     equivalent           0.515140
#                                                equivalent-weighted -1.000000
#                                                none                 0.695010
#                               collapse-layer   equivalent           0.380745
#                                                equivalent-weighted -1.000000
#                                                none                 0.242190
#                               collapse-layer-x equivalent           0.568564
#                                                equivalent-weighted -1.000000
#                                                none                 0.242236
#                               none             equivalent           0.590646
#                                                equivalent-weighted -1.000000
#                                                none                 0.705996
#                    4          collapse-all     equivalent           1.000000
#                                                equivalent-weighted -1.000000
#                                                none                 1.000000
#                               collapse-layer   equivalent           0.418329
#                                                equivalent-weighted -1.000000
#                                                none                 0.254603
#                               collapse-layer-x equivalent           0.582665
#                                                equivalent-weighted -1.000000
#                                                none                 0.261435
#                               none             equivalent           1.000000
#                                                equivalent-weighted -1.000000
#                                                none                 1.000000
#                    6          collapse-all     equivalent          -1.000000
#                                                equivalent-weighted -1.000000
#                                                none                -1.000000
#                               collapse-layer   equivalent           0.418329
#                                                equivalent-weighted -1.000000
#                                                none                 0.254603
#                               collapse-layer-x equivalent           0.582665
#                                                equivalent-weighted -1.000000
#                                                none                 0.261435
#                               none             equivalent          -1.000000
#                                                equivalent-weighted -1.000000
#                                                none                -1.000000
#           wl       2          collapse-all     equivalent           0.472297
#                                                equivalent-weighted -1.000000
#                                                none                 0.447186
#                               collapse-layer   equivalent           0.449206
#                                                equivalent-weighted -1.000000
#                                                none                 0.447186
#                               collapse-layer-x equivalent           0.164053
#                                                equivalent-weighted -1.000000
#                                                none                 0.153206
#                               none             equivalent           0.474527
#                                                equivalent-weighted -1.000000
#                                                none                 0.447688
#                    4          collapse-all     equivalent           0.920057
#                                                equivalent-weighted -1.000000
#                                                none                 0.920428
#                               collapse-layer   equivalent           0.913549
#                                                equivalent-weighted -1.000000
#                                                none                 0.921153
#                               collapse-layer-x equivalent           0.164053
#                                                equivalent-weighted -1.000000
#                                                none                 0.153206
#                               none             equivalent           0.926443
#                                                equivalent-weighted -1.000000
#                                                none                 0.923555
#                    6          collapse-all     equivalent           1.000000
#                                                equivalent-weighted -1.000000
#                                                none                 1.000000
#                               collapse-layer   equivalent           0.984222
#                                                equivalent-weighted -1.000000
#                                                none                 0.984417
#                               collapse-layer-x equivalent           0.164053
#                                                equivalent-weighted -1.000000
#                                                none                 0.153206
#                               none             equivalent           1.000000
#                                                equivalent-weighted -1.000000
#                                                none                 1.000000
#
# domain                                                              transport
# optimiser features iterations feature_pruning  data_pruning
# svr       lwl2     2          collapse-all     equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                    4          collapse-all     equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               none             equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                    6          collapse-all     equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               none             equivalent           -1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                 -1.000000
#           wl       2          collapse-all     equivalent            0.999091
#                                                equivalent-weighted  -1.000000
#                                                none                  0.999091
#                               collapse-layer   equivalent            0.999091
#                                                equivalent-weighted  -1.000000
#                                                none                  0.999091
#                               collapse-layer-x equivalent            0.077457
#                                                equivalent-weighted  -1.000000
#                                                none                  0.094817
#                               none             equivalent            0.999091
#                                                equivalent-weighted  -1.000000
#                                                none                  0.999091
#                    4          collapse-all     equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            0.077457
#                                                equivalent-weighted  -1.000000
#                                                none                  0.094817
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                    6          collapse-all     equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer   equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
#                               collapse-layer-x equivalent            0.077457
#                                                equivalent-weighted  -1.000000
#                                                none                  0.094817
#                               none             equivalent            1.000000
#                                                equivalent-weighted  -1.000000
#                                                none                  1.000000
