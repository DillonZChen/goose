# %%
from data.helper import *

# %%
df = get_train_df()
# Out:
# 100%|██████████| 360/360 [00:00<00:00, 7308.18it/s]

# %%
df = df[df.tried]
df = df[df.optimiser == "svr"]

# %%
display(df[df.pruning == "none"])
# Out:
#           domain features pruning optimiser data_generation iterations  tried  \
# 0    blocksworld       wl    none       svr            plan          1   True
# 1    blocksworld       wl    none       svr            plan          2   True
# 2    blocksworld       wl    none       svr            plan          3   True
# 3    blocksworld       wl    none       svr            plan          4   True
# 4    blocksworld       wl    none       svr            plan          5   True
# 5    blocksworld       wl    none       svr            plan          6   True
# 36    childsnack       wl    none       svr            plan          1   True
# 37    childsnack       wl    none       svr            plan          2   True
# 38    childsnack       wl    none       svr            plan          3   True
# 39    childsnack       wl    none       svr            plan          4   True
# 40    childsnack       wl    none       svr            plan          5   True
# ...

# %%
display(df[df.pruning == "collapse"])
# Out:
#           domain features   pruning optimiser data_generation iterations  \
# 18   blocksworld       wl  collapse       svr            plan          1
# 21   blocksworld       wl  collapse       svr            plan          4
# 22   blocksworld       wl  collapse       svr            plan          5
# 94         ferry       wl  collapse       svr            plan          5
# 95         ferry       wl  collapse       svr            plan          6
# 128    floortile       wl  collapse       svr            plan          3
# 129    floortile       wl  collapse       svr            plan          4
# 130    floortile       wl  collapse       svr            plan          5
# 131    floortile       wl  collapse       svr            plan          6
# 163      miconic       wl  collapse       svr            plan          2
# 164      miconic       wl  collapse       svr            plan          3
# 165      miconic       wl  collapse       svr            plan          4
# ...
